# %% [markdown]
# # <center> EDA con Pandas

# %%
#import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Dataset

# %%
# !wget -P ./../data/ https://raw.githubusercontent.com/pbonillor/DATA_SCIENCE_CON_PYTHON/main/MODULO_I/telecom_churn.csv
# Out:
# --2023-10-21 01:16:11--  https://raw.githubusercontent.com/pbonillor/DATA_SCIENCE_CON_PYTHON/main/MODULO_I/telecom_churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 310007 (303K) [text/plain]
# Saving to: ‘./../data/telecom_churn.csv’
#
# telecom_churn.csv   100%[===================>] 302.74K  --.-KB/s    in 0.04s
#
# 2023-10-21 01:16:11 (7.17 MB/s) - ‘./../data/telecom_churn.csv’ saved [310007/310007]

# %%
df = pd.read_csv('../../data/telecom_churn.csv')
print(df.shape)
df.head()
# Out:
# (3333, 21)
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df["area code"] = df["area code"].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   object
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.isnull().sum() #df.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df.describe()
# Out:
#        account length  number vmail messages  total day minutes  \
# count     3333.000000            3333.000000        3333.000000
# mean       101.064806               8.099010         179.775098
# std         39.822106              13.688365          54.467389
# min          1.000000               0.000000           0.000000
# 25%         74.000000               0.000000         143.700000
# 50%        101.000000               0.000000         179.400000
# 75%        127.000000              20.000000         216.400000
# max        243.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
df.describe(include=['object', 'bool'])
# Out:
#        state  area code phone number international plan voice mail plan  churn
# count   3333       3333         3333               3333            3333   3333
# unique    51          3         3333                  2               2      2
# top       WV        415     382-4657                 no              no  False
# freq     106       1655            1               3010            2411   2850

# %% [markdown]
# Significado de media, desviación estándar y cuartiles: [presiona aquí](https://mathbitsnotebook.com/Algebra2/Statistics/STstandardNormalDistribution.html)

# %% [markdown]
# # <center> Visualización con Pandas
# Pandas teine su propio [módulo para visualización](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %% [markdown]
# ## Análisis de varaibles categóricas:  `.bar()`, `.hbar()`, `.pie()`

# %%
list(df.select_dtypes(include=["category" , "object", "bool"]).columns)
list(df.select_dtypes(exclude=["category" , "object", "bool"]).columns)
# Out:
# ['account length',
#  'number vmail messages',
#  'total day minutes',
#  'total day calls',
#  'total day charge',
#  'total eve minutes',
#  'total eve calls',
#  'total eve charge',
#  'total night minutes',
#  'total night calls',
#  'total night charge',
#  'total intl minutes',
#  'total intl calls',
#  'total intl charge',
#  'customer service calls']

# %%
df.select_dtypes(include=['object', 'bool']).nunique()
# Out:
# state                   51
# area code                3
# phone number          3333
# international plan       2
# voice mail plan          2
# churn                    2
# dtype: int64

# %%
df["state"].value_counts().plot.bar(figsize=(10, 4));

# %%
df["state"].value_counts().plot.barh(figsize=(10, 10));

# %%
df["international plan"].value_counts().plot.pie();

# %% [markdown]
# ## Análisis de varaibles numéricas: `.hist()`, `.kde()` y `.box()`

# %%
df["account length"].plot.hist(bins=25, figsize=(10, 4));

# %%
df["account length"].plot.kde(figsize=(10, 4));

# %%
df["account length"].plot.box(vert=False, figsize=(10, 4));

# %% [markdown]
# # <center> Análisis bivariante

# %% [markdown]
# ## Variables Numérica + Numérica: `.scatter()` `.hexbin()`

# %%
df.plot.scatter(x='total day minutes', y='total day calls');

# %%
df.plot.hexbin(x='total day minutes', y='total day calls', gridsize=25);

# %%
df.plot.scatter(x='total day minutes', y='total day charge');

# %% [markdown]
# ## Variables Numérica + Categórica: `groupby` + `.hist()`

# %%
df.groupby('international plan')['account length'].plot.hist(bins=25);

# %%
df.groupby('international plan')['account length'].hist(bins=25, alpha=0.5, density=True);

# %%
df.groupby('international plan')['account length'].plot.kde();

# %% [markdown]
# ## Variables: Categórica + Categórica

# %%
g = df.groupby('churn')['customer service calls'].value_counts(normalize=True).unstack().transpose().plot.bar()

# %%
#df.groupby('International plan')['Voice mail plan'].plot.bar();

# %% [markdown]
# ## Análisis Multivariante: `df.corr()`

# %%
df.corr()
# Out:
# <ipython-input-26-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         account length  number vmail messages  \
# account length                1.000000              -0.004628
# number vmail messages        -0.004628               1.000000
# total day minutes             0.006216               0.000778
# total day calls               0.038470              -0.009548
# total day charge              0.006214               0.000776
# total eve minutes            -0.006757               0.017562
# total eve calls               0.019260              -0.005864
# total eve charge             -0.006745               0.017578
# total night minutes          -0.008955               0.007681
# total night calls            -0.013176               0.007123
# ...

# %%
df.corr().style.background_gradient()
# Out:
# <ipython-input-27-480077e722ee>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient()
# <style type="text/css">
# #T_15541_row0_col0, #T_15541_row1_col1, #T_15541_row2_col2, #T_15541_row2_col4, #T_15541_row3_col3, #T_15541_row4_col2, #T_15541_row4_col4, #T_15541_row5_col5, #T_15541_row5_col7, #T_15541_row6_col6, #T_15541_row7_col5, #T_15541_row7_col7, #T_15541_row8_col8, #T_15541_row8_col10, #T_15541_row9_col9, #T_15541_row10_col8, #T_15541_row10_col10, #T_15541_row11_col11, #T_15541_row11_col13, #T_15541_row12_col12, #T_15541_row13_col11, #T_15541_row13_col13, #T_15541_row14_col14, #T_15541_row15_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_15541_row0_col1, #T_15541_row6_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# ...
